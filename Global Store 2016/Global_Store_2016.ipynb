# %%
#importing the modules to use 
import pandas as pd
import numpy as np 
from datetime import datetime

# %%
#importing the data into the variable name store
store = pd.read_csv('global_superstore_2016.csv')

# %%
#Displaying 5 rows for our dataset
store.tail(5)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174  6/19/2015  6/19/2015        Same Day
# 51286   34337  US-2014-ZD21925140-41765   5/6/2014  5/10/2014  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147  8/26/2012  8/31/2012    Second Class
# 51288    9596   MX-2013-RB1979518-41322  2/17/2013  2/21/2013  Standard Class
# 51289    6147   MX-2013-MC1810093-41416  5/22/2013  5/26/2013    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
order_date = store['Order Date'].tolist()
order_date[-10:]
# Out:
# ['7/9/2014',
#  '6/9/2015',
#  '8/5/2015',
#  '5/30/2015',
#  '12/28/2013',
#  '6/19/2015',
#  '5/6/2014',
#  '8/26/2012',
#  '2/17/2013',
#  '5/22/2013']

# %%
order_datetime = pd.to_datetime(order_date)
order_datetime
# Out:
# DatetimeIndex(['2014-11-11', '2014-02-05', '2014-10-17', '2014-01-28',
#                '2014-11-05', '2014-06-28', '2012-11-06', '2013-04-14',
#                '2014-11-11', '2012-03-06',
#                ...
#                '2014-07-09', '2015-06-09', '2015-08-05', '2015-05-30',
#                '2013-12-28', '2015-06-19', '2014-05-06', '2012-08-26',
#                '2013-02-17', '2013-05-22'],
#               dtype='datetime64[ns]', length=51290, freq=None)

# %%
ship_date = store['Ship Date'].tolist()
ship_date[-10:]
# Out:
# ['7/9/2014',
#  '6/11/2015',
#  '8/10/2015',
#  '5/30/2015',
#  '12/31/2013',
#  '6/19/2015',
#  '5/10/2014',
#  '8/31/2012',
#  '2/21/2013',
#  '5/26/2013']

# %%
ship_datetime = pd.to_datetime(ship_date)
ship_datetime
# Out:
# DatetimeIndex(['2014-11-13', '2014-02-07', '2014-10-18', '2014-01-30',
#                '2014-11-06', '2014-07-01', '2012-11-08', '2013-04-18',
#                '2014-11-13', '2012-03-07',
#                ...
#                '2014-07-09', '2015-06-11', '2015-08-10', '2015-05-30',
#                '2013-12-31', '2015-06-19', '2014-05-10', '2012-08-31',
#                '2013-02-21', '2013-05-26'],
#               dtype='datetime64[ns]', length=51290, freq=None)

# %%
order_series = pd.Series(order_datetime, name = 'Order-Date')
order_series
# Out:
# 0       2014-11-11
# 1       2014-02-05
# 2       2014-10-17
# 3       2014-01-28
# 4       2014-11-05
#            ...
# 51285   2015-06-19
# 51286   2014-05-06
# 51287   2012-08-26
# 51288   2013-02-17
# 51289   2013-05-22
# Name: Order-Date, Length: 51290, dtype: datetime64[ns]

# %%
ship_series = pd.Series(ship_datetime, name = 'Ship_Date')
ship_series
# Out:
# 0       2014-11-13
# 1       2014-02-07
# 2       2014-10-18
# 3       2014-01-30
# 4       2014-11-06
#            ...
# 51285   2015-06-19
# 51286   2014-05-10
# 51287   2012-08-31
# 51288   2013-02-21
# 51289   2013-05-26
# Name: Ship_Date, Length: 51290, dtype: datetime64[ns]

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
store_cleaned = store[['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment','Category']]
store_cleaned.head(5)
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment    Category
# 0  AB-100151402     Aaron Bergman     Consumer  Technology
# 1     JR-162107     Justin Ritter    Corporate   Furniture
# 2     CR-127307      Craig Reiter     Consumer  Technology
# 3    KM-1637548  Katherine Murray  Home Office  Technology
# 4    RH-9495111       Rick Hansen     Consumer  Technology

# %%
store_con = pd.concat([order_series, ship_series, store['Row ID'], store['Order ID'], store['Order Date'], store['Ship Date'], store['Ship Mode'],
       store['Customer ID'], store['Customer Name'], store['Segment'],store['Category']], axis = 1)
store_con
# Out:
#       Order-Date  Ship_Date  Row ID                  Order ID  Order Date  \
# 0     2014-11-11 2014-11-13   40098  CA-2014-AB10015140-41954  11/11/2014
# 1     2014-02-05 2014-02-07   26341    IN-2014-JR162107-41675    2/5/2014
# 2     2014-10-17 2014-10-18   25330    IN-2014-CR127307-41929  10/17/2014
# 3     2014-01-28 2014-01-30   13524   ES-2014-KM1637548-41667   1/28/2014
# 4     2014-11-05 2014-11-06   47221   SG-2014-RH9495111-41948   11/5/2014
# ...          ...        ...     ...                       ...         ...
# 51285 2015-06-19 2015-06-19   29002   IN-2015-KE1642066-42174   6/19/2015
# 51286 2014-05-06 2014-05-10   34337  US-2014-ZD21925140-41765    5/6/2014
# 51287 2012-08-26 2012-08-31   31315  CA-2012-ZD21925140-41147   8/26/2012
# 51288 2013-02-17 2013-02-21    9596   MX-2013-RB1979518-41322   2/17/2013
# 51289 2013-05-22 2013-05-26    6147   MX-2013-MC1810093-41416   5/22/2013
#
#         Ship Date       Ship Mode   Customer ID       Customer Name  \
# ...

# %%
store_data = store_con.set_index('Order-Date')
store_data
# Out:
#             Ship_Date  Row ID                  Order ID  Order Date  \
# Order-Date
# 2014-11-11 2014-11-13   40098  CA-2014-AB10015140-41954  11/11/2014
# 2014-02-05 2014-02-07   26341    IN-2014-JR162107-41675    2/5/2014
# 2014-10-17 2014-10-18   25330    IN-2014-CR127307-41929  10/17/2014
# 2014-01-28 2014-01-30   13524   ES-2014-KM1637548-41667   1/28/2014
# 2014-11-05 2014-11-06   47221   SG-2014-RH9495111-41948   11/5/2014
# ...               ...     ...                       ...         ...
# 2015-06-19 2015-06-19   29002   IN-2015-KE1642066-42174   6/19/2015
# 2014-05-06 2014-05-10   34337  US-2014-ZD21925140-41765    5/6/2014
# 2012-08-26 2012-08-31   31315  CA-2012-ZD21925140-41147   8/26/2012
# 2013-02-17 2013-02-21    9596   MX-2013-RB1979518-41322   2/17/2013
# 2013-05-22 2013-05-26    6147   MX-2013-MC1810093-41416   5/22/2013
#
#              Ship Date       Ship Mode   Customer ID       Customer Name  \
# Order-Date
# ...

# %%
store_con['Ship_Date'].unique
# Out:
# <bound method Series.unique of 0       2014-11-13
# 1       2014-02-07
# 2       2014-10-18
# 3       2014-01-30
# 4       2014-11-06
#            ...
# 51285   2015-06-19
# 51286   2014-05-10
# 51287   2012-08-31
# 51288   2013-02-21
# 51289   2013-05-26
# Name: Ship_Date, Length: 51290, dtype: datetime64[ns]>

# %%
store_con.index.unique
# Out:
# <bound method Index.unique of RangeIndex(start=0, stop=51290, step=1)>

# %%
store_con.groupby(by = 'Order-Date').
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-2fe359888096> in <module>
# ----> 1 store_con.groupby(by = 'Order-Date').value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
store_data.head()
# Out:
#             Ship_Date  Row ID                  Order ID  Order Date  \
# Order-Date
# 2014-11-11 2014-11-13   40098  CA-2014-AB10015140-41954  11/11/2014
# 2014-02-05 2014-02-07   26341    IN-2014-JR162107-41675    2/5/2014
# 2014-10-17 2014-10-18   25330    IN-2014-CR127307-41929  10/17/2014
# 2014-01-28 2014-01-30   13524   ES-2014-KM1637548-41667   1/28/2014
# 2014-11-05 2014-11-06   47221   SG-2014-RH9495111-41948   11/5/2014
#
#              Ship Date     Ship Mode   Customer ID     Customer Name  \
# Order-Date
# 2014-11-11  11/13/2014   First Class  AB-100151402     Aaron Bergman
# 2014-02-05    2/7/2014  Second Class     JR-162107     Justin Ritter
# 2014-10-17  10/18/2014   First Class     CR-127307      Craig Reiter
# 2014-01-28   1/30/2014   First Class    KM-1637548  Katherine Murray
# 2014-11-05   11/6/2014      Same Day    RH-9495111       Rick Hansen
#
#                 Segment    Category
# Order-Date
# 2014-11-11     Consumer  Technology
# ...

# %%
store_data.loc['2012']
# Out:
#             Ship_Date  Row ID                  Order ID  Order Date  \
# Order-Date
# 2012-11-06 2012-11-08   30570   IN-2012-TS2134092-41219   11/6/2012
# 2012-03-06 2012-03-07   36258  CA-2012-AB10015140-40974    3/6/2012
# 2012-03-06 2012-03-07   36259  CA-2012-AB10015140-40974    3/6/2012
# 2012-12-26 2012-12-28   45794   SA-2012-MM7260110-41269  12/26/2012
# 2012-02-19 2012-02-25   39519  CA-2012-AB10015140-40958   2/19/2012
# ...               ...     ...                       ...         ...
# 2012-03-20 2012-03-25   46231    ZA-2012-AS285147-40988   3/20/2012
# 2012-08-26 2012-08-31   31317  CA-2012-ZD21925140-41147   8/26/2012
# 2012-12-02 2012-12-02   10410   ES-2012-LR1703548-41245   12/2/2012
# 2012-09-07 2012-09-09   43818    NI-2012-PO886595-41159    9/7/2012
# 2012-08-26 2012-08-31   31315  CA-2012-ZD21925140-41147   8/26/2012
#
#              Ship Date       Ship Mode   Customer ID       Customer Name  \
# Order-Date
# ...

# %%
store_data.loc['2013']
# Out:
#             Ship_Date  Row ID                  Order ID  Order Date  \
# Order-Date
# 2013-04-14 2013-04-18   31192   IN-2013-MB1808592-41378   4/14/2013
# 2013-04-19 2013-04-22   28879    ID-2013-AJ107801-41383   4/19/2013
# 2013-11-13 2013-11-13    4132   MX-2013-VF2171518-41591  11/13/2013
# 2013-08-08 2013-08-10   46630    PL-2013-AB600103-41494    8/8/2013
# 2013-02-24 2013-02-24   22999   IN-2013-BP1123058-41329   2/24/2013
# ...               ...     ...                       ...         ...
# 2013-09-28 2013-10-04   36230  CA-2013-ZC21910140-41545   9/28/2013
# 2013-08-10 2013-08-11   27081  ID-2013-EK13795102-41496   8/10/2013
# 2013-12-28 2013-12-31    9922   MX-2013-KM1637593-41636  12/28/2013
# 2013-02-17 2013-02-21    9596   MX-2013-RB1979518-41322   2/17/2013
# 2013-05-22 2013-05-26    6147   MX-2013-MC1810093-41416   5/22/2013
#
#              Ship Date       Ship Mode   Customer ID       Customer Name  \
# Order-Date
# ...

# %%
store_data.loc['2014']
# Out:
#             Ship_Date  Row ID                  Order ID  Order Date  \
# Order-Date
# 2014-11-11 2014-11-13   40098  CA-2014-AB10015140-41954  11/11/2014
# 2014-02-05 2014-02-07   26341    IN-2014-JR162107-41675    2/5/2014
# 2014-10-17 2014-10-18   25330    IN-2014-CR127307-41929  10/17/2014
# 2014-01-28 2014-01-30   13524   ES-2014-KM1637548-41667   1/28/2014
# 2014-11-05 2014-11-06   47221   SG-2014-RH9495111-41948   11/5/2014
# ...               ...     ...                       ...         ...
# 2014-04-04 2014-04-10   37195  CA-2014-ZD21925140-41733    4/4/2014
# 2014-04-04 2014-04-10   37194  CA-2014-ZD21925140-41733    4/4/2014
# 2014-09-30 2014-10-02    5596   MX-2014-SS2041082-41912   9/30/2014
# 2014-07-09 2014-07-09   35112  CA-2014-ZD21925140-41829    7/9/2014
# 2014-05-06 2014-05-10   34337  US-2014-ZD21925140-41765    5/6/2014
#
#              Ship Date       Ship Mode   Customer ID       Customer Name  \
# Order-Date
# ...

# %%
store_data.loc['2015']
# Out:
#             Ship_Date  Row ID                 Order ID  Order Date  \
# Order-Date
# 2015-07-31 2015-08-03   13779  ES-2015-BP1118545-42216   7/31/2015
# 2015-09-08 2015-09-14   12069  ES-2015-PJ1883564-42255    9/8/2015
# 2015-01-31 2015-02-01   22096   IN-2015-JS156857-42035   1/31/2015
# 2015-12-05 2015-12-07   49463  TZ-2015-RH9555129-42343   12/5/2015
# 2015-07-31 2015-08-01    1570  US-2015-NP1832582-42216   7/31/2015
# ...               ...     ...                      ...         ...
# 2015-11-29 2015-11-30   46582  TU-2015-KF6285134-42337  11/29/2015
# 2015-06-09 2015-06-11    6039  MX-2015-HG1502518-42164    6/9/2015
# 2015-08-05 2015-08-10   24175   IN-2015-DB132707-42221    8/5/2015
# 2015-05-30 2015-05-30   24105  IN-2015-KH1633058-42154   5/30/2015
# 2015-06-19 2015-06-19   29002  IN-2015-KE1642066-42174   6/19/2015
#
#              Ship Date       Ship Mode Customer ID      Customer Name  \
# Order-Date
# ...

# %%
store_data.groupby(by = store_data.index)['Order ID'].value_counts()
# Out:
# Order-Date  Order ID
# 2012-01-01  IN-2012-JH159857-40909      3
#             AG-2012-TB112803-40909      1
#             HU-2012-AT73557-40909       1
#             IT-2012-EM14140124-40909    1
# 2012-01-02  CA-2012-MM726023-40910      1
#                                        ..
# 2015-12-31  OD-2015-MW8235119-42369     1
#             TZ-2015-CK2325129-42369     1
#             TZ-2015-JA5970129-42369     1
#             UP-2015-FW4395137-42369     1
#             UP-2015-GT4755137-42369     1
# Name: Order ID, Length: 25728, dtype: int64

# %%
store_data.groupby(by = store_data.index)['Order ID'].count()
# Out:
# Order-Date
# 2012-01-01      6
# 2012-01-02      1
# 2012-01-03     20
# 2012-01-04     16
# 2012-01-05      7
#              ...
# 2015-12-27     54
# 2015-12-28     13
# 2015-12-29    116
# 2015-12-30     79
# 2015-12-31     62
# Name: Order ID, Length: 1430, dtype: int64

# %%
store_data.groupby(by = store_data.index)['Order ID'].sum()
# Out:
# Order-Date
# 2012-01-01    AG-2012-TB112803-40909IN-2012-JH159857-40909HU...
# 2012-01-02                               CA-2012-MM726023-40910
# 2012-01-03    IN-2012-KN164507-40911ID-2012-KL1664592-40911I...
# 2012-01-04    MX-2012-RA1991518-40912MX-2012-MH1778582-40912...
# 2012-01-05    MX-2012-JH1543082-40913ES-2012-MG1789045-40913...
#                                     ...
# 2015-12-27    MX-2015-MM1726051-42365KE-2015-LO717069-42365U...
# 2015-12-28    ES-2015-ZC21910139-42366ES-2015-BE1145545-4236...
# 2015-12-29    ES-2015-CD1192045-42367ID-2015-AH100757-42367E...
# 2015-12-30    ES-2015-HM14860125-42368ML-2015-BO142579-42368...
# 2015-12-31    MX-2015-EB1397518-42369IN-2015-ML1739559-42369...
# Name: Order ID, Length: 1430, dtype: object

# %%
pd.DataFrame.count?
